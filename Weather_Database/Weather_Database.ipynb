# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests

# Import the time library and the datetime module from the datetime library.
import time
from datetime import datetime

# Import the API key.
from config import weather_api_key

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -100.000, high = 100.000, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 773

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record coutn.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | viransehir
# Processing Record 2 of Set 1 | maldonado
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | asayita
# City not found. Skipping...
# Processing Record 5 of Set 1 | port elizabeth
# Processing Record 6 of Set 1 | qaanaaq
# Processing Record 7 of Set 1 | ostrovnoy
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 1 | bonfim
# Processing Record 11 of Set 1 | lusambo
# Processing Record 12 of Set 1 | riyadh
# Processing Record 13 of Set 1 | aasiaat
# Processing Record 14 of Set 1 | arlit
# Processing Record 15 of Set 1 | henties bay
# Processing Record 16 of Set 1 | sao filipe
# Processing Record 17 of Set 1 | port alfred
# Processing Record 18 of Set 1 | saldanha
# Processing Record 19 of Set 1 | carberry
# Processing Record 20 of Set 1 | bredasdorp
# Processing Record 21 of Set 1 | gbarnga
# Processing Record 22 of Set 1 | carnarvon
# Processing Record 23 of Set 1 | beloha
# Processing Record 24 of Set 1 | upernavik
# Processing Record 25 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 1 | nuuk
# Processing Record 27 of Set 1 | bilma
# Processing Record 28 of Set 1 | tafo
# Processing Record 29 of Set 1 | cidreira
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | pangnirtung
# Processing Record 32 of Set 1 | east london
# Processing Record 33 of Set 1 | buedu
# Processing Record 34 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 1 | taoudenni
# Processing Record 36 of Set 1 | faya
# Processing Record 37 of Set 1 | richards bay
# Processing Record 38 of Set 1 | adrar
# Processing Record 39 of Set 1 | buraydah
# Processing Record 40 of Set 1 | saint-philippe
# Processing Record 41 of Set 1 | castro marim
# Processing Record 42 of Set 1 | havre-saint-pierre
# Processing Record 43 of Set 1 | berlevag
# Processing Record 44 of Set 1 | teya
# Processing Record 45 of Set 1 | conceicao da barra
# Processing Record 46 of Set 1 | quatre cocos
# Processing Record 47 of Set 1 | lagoa
# Processing Record 48 of Set 1 | ribeira grande
# Processing Record 49 of Set 1 | krapivinskiy
# Processing Record 50 of Set 1 | puerto ayora
# Processing Record 1 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 2 | coquimbo
# Processing Record 3 of Set 2 | mount darwin
# Processing Record 4 of Set 2 | khor
# Processing Record 5 of Set 2 | plaster rock
# Processing Record 6 of Set 2 | chuy
# Processing Record 7 of Set 2 | saint-augustin
# Processing Record 8 of Set 2 | namibe
# Processing Record 9 of Set 2 | hermanus
# Processing Record 10 of Set 2 | tasiilaq
# Processing Record 11 of Set 2 | thompson
# Processing Record 12 of Set 2 | chimbote
# Processing Record 13 of Set 2 | zlotow
# Processing Record 14 of Set 2 | trelleborg
# Processing Record 15 of Set 2 | matara
# Processing Record 16 of Set 2 | clyde river
# Processing Record 17 of Set 2 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 18 of Set 2 | gravdal
# Processing Record 19 of Set 2 | kedrovyy
# Processing Record 20 of Set 2 | chake chake
# Processing Record 21 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 22 of Set 2 | biu
# Processing Record 23 of Set 2 | los llanos de aridane
# Processing Record 24 of Set 2 | albany
# Processing Record 25 of Set 2 | sayyan
# Processing Record 26 of Set 2 | puerto madero
# Processing Record 27 of Set 2 | salina cruz
# Processing Record 28 of Set 2 | cape town
# Processing Record 29 of Set 2 | matay
# Processing Record 30 of Set 2 | sipe sipe
# Processing Record 31 of Set 2 | mar del plata
# Processing Record 32 of Set 2 | bambous virieux
# Processing Record 33 of Set 2 | vila franca do campo
# Processing Record 34 of Set 2 | kalabo
# Processing Record 35 of Set 2 | aksarka
# Processing Record 36 of Set 2 | khatanga
# Processing Record 37 of Set 2 | zemio
# Processing Record 38 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 2 | padang
# Processing Record 40 of Set 2 | bengkulu
# Processing Record 41 of Set 2 | severnyy
# Processing Record 42 of Set 2 | gat
# Processing Record 43 of Set 2 | ponta do sol
# Processing Record 44 of Set 2 | longyearbyen
# Processing Record 45 of Set 2 | ancud
# Processing Record 46 of Set 2 | kamenka
# Processing Record 47 of Set 2 | abu samrah
# Processing Record 48 of Set 2 | umm lajj
# Processing Record 49 of Set 2 | sakakah
# Processing Record 50 of Set 2 | kita
# Processing Record 1 of Set 3 | castro
# Processing Record 2 of Set 3 | darab
# Processing Record 3 of Set 3 | tonj
# Processing Record 4 of Set 3 | mushie
# Processing Record 5 of Set 3 | maxixe
# Processing Record 6 of Set 3 | carballo
# Processing Record 7 of Set 3 | strezhevoy
# Processing Record 8 of Set 3 | moguer
# Processing Record 9 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 3 | cayenne
# Processing Record 11 of Set 3 | cururupu
# Processing Record 12 of Set 3 | jamestown
# Processing Record 13 of Set 3 | yumen
# Processing Record 14 of Set 3 | motupe
# Processing Record 15 of Set 3 | lebu
# Processing Record 16 of Set 3 | rio gallegos
# Processing Record 17 of Set 3 | codrington
# Processing Record 18 of Set 3 | zanjan
# Processing Record 19 of Set 3 | adre
# Processing Record 20 of Set 3 | dikson
# Processing Record 21 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 3 | chapais
# Processing Record 23 of Set 3 | jijiga
# Processing Record 24 of Set 3 | ada
# Processing Record 25 of Set 3 | dali
# Processing Record 26 of Set 3 | arraial do cabo
# Processing Record 27 of Set 3 | hofn
# Processing Record 28 of Set 3 | gemena
# Processing Record 29 of Set 3 | iguatemi
# Processing Record 30 of Set 3 | puri
# Processing Record 31 of Set 3 | mchinji
# Processing Record 32 of Set 3 | puerto baquerizo moreno
# Processing Record 33 of Set 3 | odweyne
# Processing Record 34 of Set 3 | mandla
# Processing Record 35 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 36 of Set 3 | victoria
# Processing Record 37 of Set 3 | vila praia de ancora
# Processing Record 38 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 39 of Set 3 | fort-shevchenko
# Processing Record 40 of Set 3 | torres
# Processing Record 41 of Set 3 | iqaluit
# Processing Record 42 of Set 3 | souillac
# Processing Record 43 of Set 3 | saint-pierre
# Processing Record 44 of Set 3 | bria
# Processing Record 45 of Set 3 | oranjestad
# Processing Record 46 of Set 3 | naranjal
# Processing Record 47 of Set 3 | karmana
# City not found. Skipping...
# Processing Record 48 of Set 3 | meulaboh
# Processing Record 49 of Set 3 | qafqafa
# Processing Record 50 of Set 3 | paramonga
# Processing Record 1 of Set 4 | jiddah
# City not found. Skipping...
# Processing Record 2 of Set 4 | lasa
# Processing Record 3 of Set 4 | xining
# Processing Record 4 of Set 4 | labuhan
# Processing Record 5 of Set 4 | khandwa
# Processing Record 6 of Set 4 | dapaong
# Processing Record 7 of Set 4 | fez
# Processing Record 8 of Set 4 | longlac
# City not found. Skipping...
# Processing Record 9 of Set 4 | ambodifototra
# City not found. Skipping...
# Processing Record 10 of Set 4 | bonavista
# Processing Record 11 of Set 4 | grindavik
# Processing Record 12 of Set 4 | beausoleil
# Processing Record 13 of Set 4 | oussouye
# Processing Record 14 of Set 4 | akyab
# Processing Record 15 of Set 4 | touros
# Processing Record 16 of Set 4 | gazojak
# Processing Record 17 of Set 4 | gamba
# Processing Record 18 of Set 4 | volksrust
# Processing Record 19 of Set 4 | margate
# Processing Record 20 of Set 4 | georgetown
# Processing Record 21 of Set 4 | puerto escondido
# Processing Record 22 of Set 4 | saurimo
# Processing Record 23 of Set 4 | keti bandar
# Processing Record 24 of Set 4 | aliganj
# Processing Record 25 of Set 4 | yellowknife
# Processing Record 26 of Set 4 | zwedru
# Processing Record 27 of Set 4 | verkhnyaya inta
# Processing Record 28 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 4 | omboue
# Processing Record 31 of Set 4 | olafsvik
# Processing Record 32 of Set 4 | karakendzha
# City not found. Skipping...
# Processing Record 33 of Set 4 | necochea
# Processing Record 34 of Set 4 | sorland
# Processing Record 35 of Set 4 | serchhip
# Processing Record 36 of Set 4 | yankton
# Processing Record 37 of Set 4 | damaturu
# Processing Record 38 of Set 4 | andenes
# Processing Record 39 of Set 4 | salalah
# Processing Record 40 of Set 4 | wad rawah
# Processing Record 41 of Set 4 | yabelo
# Processing Record 42 of Set 4 | iberia
# Processing Record 43 of Set 4 | vir
# Processing Record 44 of Set 4 | san-pedro
# Processing Record 45 of Set 4 | sechura
# Processing Record 46 of Set 4 | mehamn
# Processing Record 47 of Set 4 | sabha
# Processing Record 48 of Set 4 | brae
# Processing Record 49 of Set 4 | sioux lookout
# Processing Record 50 of Set 4 | svetlogorsk
# Processing Record 1 of Set 5 | hithadhoo
# Processing Record 2 of Set 5 | uk
# City not found. Skipping...
# Processing Record 3 of Set 5 | caravelas
# Processing Record 4 of Set 5 | karema
# Processing Record 5 of Set 5 | bogande
# Processing Record 6 of Set 5 | wattegama
# Processing Record 7 of Set 5 | yamethin
# Processing Record 8 of Set 5 | kruisfontein
# Processing Record 9 of Set 5 | giraltovce
# Processing Record 10 of Set 5 | cholet
# Processing Record 11 of Set 5 | manavalakurichi
# Processing Record 12 of Set 5 | trairi
# Processing Record 13 of Set 5 | mehran
# Processing Record 14 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 15 of Set 5 | gorom-gorom
# Processing Record 16 of Set 5 | maarianhamina
# Processing Record 17 of Set 5 | ayorou
# Processing Record 18 of Set 5 | hualmay
# Processing Record 19 of Set 5 | uige
# Processing Record 20 of Set 5 | laguna
# Processing Record 21 of Set 5 | saint-joseph
# Processing Record 22 of Set 5 | kytlym
# City not found. Skipping...
# Processing Record 23 of Set 5 | nokaneng
# Processing Record 24 of Set 5 | salisbury
# Processing Record 25 of Set 5 | jardim
# Processing Record 26 of Set 5 | mana
# Processing Record 27 of Set 5 | garavuti
# Processing Record 28 of Set 5 | mayor pablo lagerenza
# Processing Record 29 of Set 5 | baghdad
# Processing Record 30 of Set 5 | jalpan
# Processing Record 31 of Set 5 | klaksvik
# Processing Record 32 of Set 5 | saint-francois
# Processing Record 33 of Set 5 | quime
# Processing Record 34 of Set 5 | nizwa
# Processing Record 35 of Set 5 | fonte boa
# Processing Record 36 of Set 5 | marzuq
# Processing Record 37 of Set 5 | tirano
# Processing Record 38 of Set 5 | sabla
# Processing Record 39 of Set 5 | orasac
# Processing Record 40 of Set 5 | veere
# Processing Record 41 of Set 5 | paamiut
# Processing Record 42 of Set 5 | puerto castilla
# Processing Record 43 of Set 5 | wellington
# Processing Record 44 of Set 5 | kukmor
# Processing Record 45 of Set 5 | nanortalik
# Processing Record 46 of Set 5 | lalibela
# Processing Record 47 of Set 5 | stokmarknes
# Processing Record 48 of Set 5 | bathsheba
# Processing Record 49 of Set 5 | mahebourg
# Processing Record 50 of Set 5 | medea
# Processing Record 1 of Set 6 | wawa
# Processing Record 2 of Set 6 | atar
# Processing Record 3 of Set 6 | bethanien
# Processing Record 4 of Set 6 | khorramshahr
# Processing Record 5 of Set 6 | tessalit
# Processing Record 6 of Set 6 | ambilobe
# Processing Record 7 of Set 6 | tartagal
# Processing Record 8 of Set 6 | buzmeyin
# Processing Record 9 of Set 6 | tiznit
# Processing Record 10 of Set 6 | bababe
# City not found. Skipping...
# Processing Record 11 of Set 6 | mugur-aksy
# Processing Record 12 of Set 6 | copiapo
# Processing Record 13 of Set 6 | chilca
# Processing Record 14 of Set 6 | sohag
# Processing Record 15 of Set 6 | novo cruzeiro
# Processing Record 16 of Set 6 | korla
# Processing Record 17 of Set 6 | havoysund
# Processing Record 18 of Set 6 | antofagasta
# Processing Record 19 of Set 6 | harlingen
# Processing Record 20 of Set 6 | terranuova bracciolini
# Processing Record 21 of Set 6 | tambul
# City not found. Skipping...
# Processing Record 22 of Set 6 | nadym
# Processing Record 23 of Set 6 | gazanjyk
# Processing Record 24 of Set 6 | nedjo
# Processing Record 25 of Set 6 | rocha
# Processing Record 26 of Set 6 | mayumba
# Processing Record 27 of Set 6 | uvinza
# Processing Record 28 of Set 6 | kollumerland
# City not found. Skipping...
# Processing Record 29 of Set 6 | bani
# Processing Record 30 of Set 6 | nagpur
# Processing Record 31 of Set 6 | inirida
# Processing Record 32 of Set 6 | isabela
# Processing Record 33 of Set 6 | zaysan
# Processing Record 34 of Set 6 | daitari
# Processing Record 35 of Set 6 | kachiry
# Processing Record 36 of Set 6 | almeirim
# Processing Record 37 of Set 6 | san cristobal
# Processing Record 38 of Set 6 | tromso
# Processing Record 39 of Set 6 | kutum
# Processing Record 40 of Set 6 | seydi
# Processing Record 41 of Set 6 | granada
# Processing Record 42 of Set 6 | barcelos
# Processing Record 43 of Set 6 | ostersund
# Processing Record 44 of Set 6 | les cayes
# Processing Record 45 of Set 6 | roros
# Processing Record 46 of Set 6 | mazyr
# Processing Record 47 of Set 6 | marsh harbour
# Processing Record 48 of Set 6 | okandja
# City not found. Skipping...
# Processing Record 49 of Set 6 | ardistan
# City not found. Skipping...
# Processing Record 50 of Set 6 | ponta delgada
# Processing Record 1 of Set 7 | vardo
# Processing Record 2 of Set 7 | urubicha
# Processing Record 3 of Set 7 | orebro
# Processing Record 4 of Set 7 | leh
# Processing Record 5 of Set 7 | mwanza
# Processing Record 6 of Set 7 | hami
# Processing Record 7 of Set 7 | manosque
# Processing Record 8 of Set 7 | hit
# Processing Record 9 of Set 7 | porto novo
# Processing Record 10 of Set 7 | blonduos
# City not found. Skipping...
# Processing Record 11 of Set 7 | beroroha
# Processing Record 12 of Set 7 | torbay
# Processing Record 13 of Set 7 | dwarka
# Processing Record 14 of Set 7 | udankudi
# Processing Record 15 of Set 7 | boende
# Processing Record 16 of Set 7 | garowe
# Processing Record 17 of Set 7 | morant bay
# Processing Record 18 of Set 7 | srivardhan
# Processing Record 19 of Set 7 | pochutla
# Processing Record 20 of Set 7 | cockburn town
# Processing Record 21 of Set 7 | sambava
# Processing Record 22 of Set 7 | sokoni
# Processing Record 23 of Set 7 | winona
# Processing Record 24 of Set 7 | nizhnekamsk
# Processing Record 25 of Set 7 | kashary
# Processing Record 26 of Set 7 | san jose del guaviare
# Processing Record 27 of Set 7 | varkkallai
# Processing Record 28 of Set 7 | huarmey
# Processing Record 29 of Set 7 | tokat
# Processing Record 30 of Set 7 | nahrin
# Processing Record 31 of Set 7 | kiruna
# Processing Record 32 of Set 7 | awjilah
# Processing Record 33 of Set 7 | faranah
# Processing Record 34 of Set 7 | khipro
# Processing Record 35 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 7 | sal rei
# Processing Record 37 of Set 7 | geraldton
# Processing Record 38 of Set 7 | kasongo-lunda
# Processing Record 39 of Set 7 | mumford
# Processing Record 40 of Set 7 | rimouski
# Processing Record 41 of Set 7 | la virtud
# Processing Record 42 of Set 7 | comodoro rivadavia
# Processing Record 43 of Set 7 | guelengdeng
# City not found. Skipping...
# Processing Record 44 of Set 7 | general roca
# Processing Record 45 of Set 7 | marawi
# Processing Record 46 of Set 7 | punta alta
# Processing Record 47 of Set 7 | mitsamiouli
# Processing Record 48 of Set 7 | venice
# Processing Record 49 of Set 7 | dekar
# Processing Record 50 of Set 7 | ilulissat
# Processing Record 1 of Set 8 | rosetta
# Processing Record 2 of Set 8 | mairang
# Processing Record 3 of Set 8 | novo aripuana
# Processing Record 4 of Set 8 | qaqortoq
# Processing Record 5 of Set 8 | plettenberg bay
# Processing Record 6 of Set 8 | hun
# Processing Record 7 of Set 8 | matinhos
# Processing Record 8 of Set 8 | kaarina
# Processing Record 9 of Set 8 | kalmar
# Processing Record 10 of Set 8 | talnakh
# Processing Record 11 of Set 8 | maceio
# Processing Record 12 of Set 8 | santiago
# Processing Record 13 of Set 8 | edgewater
# Processing Record 14 of Set 8 | puerto quijarro
# Processing Record 15 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 16 of Set 8 | maniitsoq
# Processing Record 17 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 18 of Set 8 | karasburg
# Processing Record 19 of Set 8 | batsfjord
# Processing Record 20 of Set 8 | lahan
# Processing Record 21 of Set 8 | kavaratti
# Processing Record 22 of Set 8 | tombouctou
# Processing Record 23 of Set 8 | sabang
# Processing Record 24 of Set 8 | masalli
# Processing Record 25 of Set 8 | la palma
# Processing Record 26 of Set 8 | tawang
# Processing Record 27 of Set 8 | moose factory
# Processing Record 28 of Set 8 | goderich
# Processing Record 29 of Set 8 | santa maria
# Processing Record 30 of Set 8 | qandala
# Processing Record 31 of Set 8 | caranavi
# Processing Record 32 of Set 8 | bajo baudo
# City not found. Skipping...
# Processing Record 33 of Set 8 | storsteinnes
# Processing Record 34 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 35 of Set 8 | mafinga
# Processing Record 36 of Set 8 | maksi
# Processing Record 37 of Set 8 | bandarbeyla
# Processing Record 38 of Set 8 | dhidhdhoo
# Processing Record 39 of Set 8 | sur
# Processing Record 40 of Set 8 | mount pleasant
# Processing Record 41 of Set 8 | nchelenge
# Processing Record 42 of Set 8 | ulaangom
# Processing Record 43 of Set 8 | saint george
# Processing Record 44 of Set 8 | turochak
# Processing Record 45 of Set 8 | ormara
# Processing Record 46 of Set 8 | jilib
# Processing Record 47 of Set 8 | san carlos de bariloche
# Processing Record 48 of Set 8 | viedma
# Processing Record 49 of Set 8 | tshela
# Processing Record 50 of Set 8 | neuquen
# Processing Record 1 of Set 9 | poroshkovo
# Processing Record 2 of Set 9 | lima
# Processing Record 3 of Set 9 | dingle
# Processing Record 4 of Set 9 | zhezkazgan
# Processing Record 5 of Set 9 | kibaya
# Processing Record 6 of Set 9 | olden
# Processing Record 7 of Set 9 | las palmas
# Processing Record 8 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 9 of Set 9 | pisco
# Processing Record 10 of Set 9 | arandis
# Processing Record 11 of Set 9 | ilave
# Processing Record 12 of Set 9 | mirabad
# Processing Record 13 of Set 9 | bitam
# Processing Record 14 of Set 9 | jiuquan
# Processing Record 15 of Set 9 | lamu
# Processing Record 16 of Set 9 | champerico
# Processing Record 17 of Set 9 | bizhbulyak
# Processing Record 18 of Set 9 | thunder bay
# Processing Record 19 of Set 9 | jalu
# Processing Record 20 of Set 9 | stepnoye
# Processing Record 21 of Set 9 | puerto ayacucho
# Processing Record 22 of Set 9 | lixourion
# Processing Record 23 of Set 9 | oktyabrskoye
# Processing Record 24 of Set 9 | rockland
# Processing Record 25 of Set 9 | bitkine
# Processing Record 26 of Set 9 | inhambane
# Processing Record 27 of Set 9 | tucuma
# Processing Record 28 of Set 9 | syriam
# Processing Record 29 of Set 9 | tilbury
# Processing Record 30 of Set 9 | calvia
# Processing Record 31 of Set 9 | atkarsk
# Processing Record 32 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 9 | samagaltay
# Processing Record 34 of Set 9 | deogarh
# Processing Record 35 of Set 9 | zheleznodorozhnyy
# Processing Record 36 of Set 9 | goose creek
# Processing Record 37 of Set 9 | sisimiut
# Processing Record 38 of Set 9 | vengerovo
# Processing Record 39 of Set 9 | emba
# Processing Record 40 of Set 9 | camacha
# Processing Record 41 of Set 9 | chegem
# Processing Record 42 of Set 9 | iroquois falls
# Processing Record 43 of Set 9 | diego de almagro
# Processing Record 44 of Set 9 | norrkoping
# Processing Record 45 of Set 9 | kyotera
# Processing Record 46 of Set 9 | skjervoy
# Processing Record 47 of Set 9 | maragua
# Processing Record 48 of Set 9 | maragheh
# Processing Record 49 of Set 9 | cascais
# Processing Record 50 of Set 9 | mto wa mbu
# Processing Record 1 of Set 10 | parana
# Processing Record 2 of Set 10 | cartagena del chaira
# Processing Record 3 of Set 10 | alghero
# Processing Record 4 of Set 10 | baykit
# Processing Record 5 of Set 10 | marfino
# Processing Record 6 of Set 10 | kananga
# Processing Record 7 of Set 10 | olinda
# Processing Record 8 of Set 10 | kouroussa
# Processing Record 9 of Set 10 | tocache
# Processing Record 10 of Set 10 | lovosice
# Processing Record 11 of Set 10 | kasempa
# Processing Record 12 of Set 10 | bousso
# Processing Record 13 of Set 10 | chicama
# Processing Record 14 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 10 | bay roberts
# Processing Record 16 of Set 10 | verkhniye kigi
# Processing Record 17 of Set 10 | muisne
# Processing Record 18 of Set 10 | mungaa
# Processing Record 19 of Set 10 | lyuban
# Processing Record 20 of Set 10 | bayan
# Processing Record 21 of Set 10 | husavik
# Processing Record 22 of Set 10 | koslan
# Processing Record 23 of Set 10 | port blair
# Processing Record 24 of Set 10 | balvi
# Processing Record 25 of Set 10 | vysotskoye
# Processing Record 26 of Set 10 | lakhdenpokhya
# Processing Record 27 of Set 10 | praia
# Processing Record 28 of Set 10 | saint anthony
# Processing Record 29 of Set 10 | port-cartier
# Processing Record 30 of Set 10 | khairpur nathan shah
# Processing Record 31 of Set 10 | totness
# Processing Record 32 of Set 10 | senigallia
# Processing Record 33 of Set 10 | tevriz
# Processing Record 34 of Set 10 | draguignan
# Processing Record 35 of Set 10 | karpathos
# Processing Record 36 of Set 10 | jati
# Processing Record 37 of Set 10 | villa altagracia
# Processing Record 38 of Set 10 | ochakiv
# Processing Record 39 of Set 10 | leshukonskoye
# Processing Record 40 of Set 10 | la brea
# Processing Record 41 of Set 10 | kefalos
# Processing Record 42 of Set 10 | teknaf
# Processing Record 43 of Set 10 | methoni
# Processing Record 44 of Set 10 | fatehabad
# Processing Record 45 of Set 10 | luderitz
# Processing Record 46 of Set 10 | narsaq
# Processing Record 47 of Set 10 | ghanzi
# Processing Record 48 of Set 10 | arona
# Processing Record 49 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 50 of Set 10 | hamilton
# Processing Record 1 of Set 11 | kuryk
# Processing Record 2 of Set 11 | goure
# Processing Record 3 of Set 11 | savannah bight
# Processing Record 4 of Set 11 | usinsk
# Processing Record 5 of Set 11 | bombay
# Processing Record 6 of Set 11 | voineasa
# Processing Record 7 of Set 11 | taltal
# Processing Record 8 of Set 11 | rawson
# Processing Record 9 of Set 11 | znamenskoye
# Processing Record 10 of Set 11 | bafoulabe
# Processing Record 11 of Set 11 | bannu
# Processing Record 12 of Set 11 | jacareacanga
# Processing Record 13 of Set 11 | mabaruma
# Processing Record 14 of Set 11 | quixada
# Processing Record 15 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 16 of Set 11 | panjab
# Processing Record 17 of Set 11 | shieli
# Processing Record 18 of Set 11 | araci
# Processing Record 19 of Set 11 | puiesti
# Processing Record 20 of Set 11 | vieste
# Processing Record 21 of Set 11 | dianopolis
# City not found. Skipping...
# Processing Record 22 of Set 11 | aljezur
# Processing Record 23 of Set 11 | coruripe
# Processing Record 24 of Set 11 | butzow
# Processing Record 25 of Set 11 | andijon
# Processing Record 26 of Set 11 | lundazi
# Processing Record 27 of Set 11 | acajutla
# Processing Record 28 of Set 11 | mergui
# City not found. Skipping...
# Processing Record 29 of Set 11 | kilindoni
# Processing Record 30 of Set 11 | karamay
# City not found. Skipping...
# Processing Record 31 of Set 11 | kabinda
# Processing Record 32 of Set 11 | komatipoort
# Processing Record 33 of Set 11 | niamey
# Processing Record 34 of Set 11 | san pedro
# Processing Record 35 of Set 11 | boguchany
# Processing Record 36 of Set 11 | nouadhibou
# Processing Record 37 of Set 11 | turayf
# Processing Record 38 of Set 11 | stephenville
# Processing Record 39 of Set 11 | nyaunglebin
# Processing Record 40 of Set 11 | scottsburgh
# City not found. Skipping...
# Processing Record 41 of Set 11 | ketou
# Processing Record 42 of Set 11 | morgan city
# Processing Record 43 of Set 11 | bokspits
# City not found. Skipping...
# Processing Record 44 of Set 11 | kismayo
# Processing Record 45 of Set 11 | kirovskiy
# Processing Record 46 of Set 11 | kitchener
# Processing Record 47 of Set 11 | yenagoa
# Processing Record 48 of Set 11 | mislinja
# Processing Record 49 of Set 11 | houma
# Processing Record 50 of Set 11 | los andes
# Processing Record 1 of Set 12 | itarema
# Processing Record 2 of Set 12 | farrukhnagar
# Processing Record 3 of Set 12 | bandikui
# Processing Record 4 of Set 12 | ozgon
# City not found. Skipping...
# Processing Record 5 of Set 12 | havelock
# Processing Record 6 of Set 12 | gracac
# Processing Record 7 of Set 12 | gerede
# Processing Record 8 of Set 12 | lucapa
# Processing Record 9 of Set 12 | ruy barbosa
# Processing Record 10 of Set 12 | borskoye
# Processing Record 11 of Set 12 | kargil
# Processing Record 12 of Set 12 | najran
# Processing Record 13 of Set 12 | aguimes
# Processing Record 14 of Set 12 | lashio
# Processing Record 15 of Set 12 | moissala
# Processing Record 16 of Set 12 | iskateley
# Processing Record 17 of Set 12 | hauterive
# Processing Record 18 of Set 12 | varhaug
# Processing Record 19 of Set 12 | narva-joesuu
# Processing Record 20 of Set 12 | vagay
# Processing Record 21 of Set 12 | ampanihy
# Processing Record 22 of Set 12 | santa marta
# Processing Record 23 of Set 12 | hyeres
# Processing Record 24 of Set 12 | krasnoshchekovo
# Processing Record 25 of Set 12 | tefe
# Processing Record 26 of Set 12 | guayaramerin
# Processing Record 27 of Set 12 | labrea
# Processing Record 28 of Set 12 | uralskiy
# City not found. Skipping...
# Processing Record 29 of Set 12 | togur
# Processing Record 30 of Set 12 | killybegs
# Processing Record 31 of Set 12 | horn
# Processing Record 32 of Set 12 | lampang
# Processing Record 33 of Set 12 | jiayuguan
# Processing Record 34 of Set 12 | saint-gabriel
# Processing Record 35 of Set 12 | kastamonu
# Processing Record 36 of Set 12 | vila velha
# Processing Record 37 of Set 12 | karia
# Processing Record 38 of Set 12 | kalmunai
# Processing Record 39 of Set 12 | ilabaya
# Processing Record 40 of Set 12 | washington
# Processing Record 41 of Set 12 | panormos
# Processing Record 42 of Set 12 | aquiraz
# Processing Record 43 of Set 12 | trincomalee
# Processing Record 44 of Set 12 | dalvik
# Processing Record 45 of Set 12 | constantine
# Processing Record 46 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 47 of Set 12 | port shepstone
# Processing Record 48 of Set 12 | almargem do bispo
# Processing Record 49 of Set 12 | harper
# Processing Record 50 of Set 12 | ventspils
# Processing Record 1 of Set 13 | sandwick
# Processing Record 2 of Set 13 | bandundu
# Processing Record 3 of Set 13 | kathor
# Processing Record 4 of Set 13 | kindu
# Processing Record 5 of Set 13 | belomorsk
# Processing Record 6 of Set 13 | brokopondo
# Processing Record 7 of Set 13 | vestmannaeyjar
# Processing Record 8 of Set 13 | peniche
# Processing Record 9 of Set 13 | altay
# Processing Record 10 of Set 13 | lake city
# Processing Record 11 of Set 13 | tuggurt
# City not found. Skipping...
# Processing Record 12 of Set 13 | corner brook
# Processing Record 13 of Set 13 | tocopilla
# Processing Record 14 of Set 13 | penzance
# Processing Record 15 of Set 13 | bani walid
# Processing Record 16 of Set 13 | zhanatas
# City not found. Skipping...
# Processing Record 17 of Set 13 | mocambique
# City not found. Skipping...
# Processing Record 18 of Set 13 | biltine
# Processing Record 19 of Set 13 | andarab
# City not found. Skipping...
# Processing Record 20 of Set 13 | tarn taran
# Processing Record 21 of Set 13 | akureyri
# Processing Record 22 of Set 13 | reconquista
# Processing Record 23 of Set 13 | betsiamites
# Processing Record 24 of Set 13 | grand-lahou
# Processing Record 25 of Set 13 | witu
# Processing Record 26 of Set 13 | sharjah
# Processing Record 27 of Set 13 | upington
# Processing Record 28 of Set 13 | daoukro
# Processing Record 29 of Set 13 | shelburne
# Processing Record 30 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 31 of Set 13 | hot springs
# Processing Record 32 of Set 13 | walvis bay
# Processing Record 33 of Set 13 | oudtshoorn
# Processing Record 34 of Set 13 | kajaani
# Processing Record 35 of Set 13 | vallenar
# Processing Record 36 of Set 13 | dzerzhinsk
# Processing Record 37 of Set 13 | natitingou
# Processing Record 38 of Set 13 | ballina
# Processing Record 39 of Set 13 | superior
# Processing Record 40 of Set 13 | malatya
# Processing Record 41 of Set 13 | miraflores
# Processing Record 42 of Set 13 | qasigiannguit
# Processing Record 43 of Set 13 | sao luiz gonzaga
# Processing Record 44 of Set 13 | batticaloa
# Processing Record 45 of Set 13 | mitu
# Processing Record 46 of Set 13 | beckley
# Processing Record 47 of Set 13 | mezhdurechenskiy
# Processing Record 48 of Set 13 | tete
# Processing Record 49 of Set 13 | bochnia
# Processing Record 50 of Set 13 | turukhansk
# Processing Record 1 of Set 14 | ekibastuz
# Processing Record 2 of Set 14 | jutai
# Processing Record 3 of Set 14 | karachi
# Processing Record 4 of Set 14 | afgoye
# City not found. Skipping...
# Processing Record 5 of Set 14 | bosaso
# Processing Record 6 of Set 14 | puerto el triunfo
# Processing Record 7 of Set 14 | bubaque
# Processing Record 8 of Set 14 | timra
# Processing Record 9 of Set 14 | muros
# Processing Record 10 of Set 14 | sao jose da coroa grande
# Processing Record 11 of Set 14 | nacala
# Processing Record 12 of Set 14 | khuzdar
# Processing Record 13 of Set 14 | chokwe
# Processing Record 14 of Set 14 | stantsionno-oyashinskiy
# Processing Record 15 of Set 14 | kalmeshwar
# Processing Record 16 of Set 14 | marialva
# Processing Record 17 of Set 14 | yanam
# Processing Record 18 of Set 14 | serrinha
# Processing Record 19 of Set 14 | movila
# Processing Record 20 of Set 14 | besancon
# Processing Record 21 of Set 14 | hereford
# Processing Record 22 of Set 14 | gusau
# Processing Record 23 of Set 14 | le port
# Processing Record 24 of Set 14 | santa fe
# Processing Record 25 of Set 14 | satao
# Processing Record 26 of Set 14 | misratah
# Processing Record 27 of Set 14 | acari
# Processing Record 28 of Set 14 | awbari
# Processing Record 29 of Set 14 | bonthe
# Processing Record 30 of Set 14 | mercedes
# Processing Record 31 of Set 14 | galveston
# Processing Record 32 of Set 14 | kennett
# Processing Record 33 of Set 14 | boysun
# Processing Record 34 of Set 14 | jalingo
# Processing Record 35 of Set 14 | lumeje
# Processing Record 36 of Set 14 | denizli
# Processing Record 37 of Set 14 | mogadishu
# Processing Record 38 of Set 14 | devils lake
# Processing Record 39 of Set 14 | talmenka
# Processing Record 40 of Set 14 | tarrega
# Processing Record 41 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 42 of Set 14 | bida
# Processing Record 43 of Set 14 | kilis
# Processing Record 44 of Set 14 | paracuru
# Processing Record 45 of Set 14 | cassilandia
# Processing Record 46 of Set 14 | nosy varika
# Processing Record 47 of Set 14 | lubango
# Processing Record 48 of Set 14 | belyy yar
# Processing Record 49 of Set 14 | rincon
# Processing Record 50 of Set 14 | lysychovo
# Processing Record 1 of Set 15 | diamantino
# Processing Record 2 of Set 15 | port-gentil
# Processing Record 3 of Set 15 | torbat-e jam
# Processing Record 4 of Set 15 | marsa matruh
# Processing Record 5 of Set 15 | moratuwa
# Processing Record 6 of Set 15 | julana
# City not found. Skipping...
# Processing Record 7 of Set 15 | mahibadhoo
# Processing Record 8 of Set 15 | abapo
# Processing Record 9 of Set 15 | oriximina
# Processing Record 10 of Set 15 | sarwar
# Processing Record 11 of Set 15 | gangapur
# Processing Record 12 of Set 15 | bonoua
# Processing Record 13 of Set 15 | parrsboro
# Processing Record 14 of Set 15 | skibbereen
# Processing Record 15 of Set 15 | menongue
# Processing Record 16 of Set 15 | plerin
# Processing Record 17 of Set 15 | rolla
# Processing Record 18 of Set 15 | kafanchan
# Processing Record 19 of Set 15 | inta
# Processing Record 20 of Set 15 | joshimath
# Processing Record 21 of Set 15 | pedro ii
# Processing Record 22 of Set 15 | valparaiso
# Processing Record 23 of Set 15 | belmonte
# Processing Record 24 of Set 15 | puerto leguizamo
# Processing Record 25 of Set 15 | thiruvananthapuram
# Processing Record 26 of Set 15 | sao joao do piaui
# Processing Record 27 of Set 15 | myitkyina
# Processing Record 28 of Set 15 | oranjemund
# Processing Record 29 of Set 15 | pangody
# Processing Record 30 of Set 15 | san rafael
# Processing Record 31 of Set 15 | kitgum
# Processing Record 32 of Set 15 | groningen
# Processing Record 33 of Set 15 | yurgamysh
# Processing Record 34 of Set 15 | rubi
# Processing Record 35 of Set 15 | wabana
# Processing Record 36 of Set 15 | ambanja
# Processing Record 37 of Set 15 | ambovombe
# Processing Record 38 of Set 15 | sao gabriel da cachoeira
# Processing Record 39 of Set 15 | aransas pass
# Processing Record 40 of Set 15 | leca da palmeira
# Processing Record 41 of Set 15 | fereydunshahr
# Processing Record 42 of Set 15 | pimenta bueno
# Processing Record 43 of Set 15 | ostroleka
# Processing Record 44 of Set 15 | rockport
# Processing Record 45 of Set 15 | huazolotitlan
# City not found. Skipping...
# Processing Record 46 of Set 15 | salym
# Processing Record 47 of Set 15 | lujan
# Processing Record 48 of Set 15 | matagami
# Processing Record 49 of Set 15 | hambantota
# Processing Record 50 of Set 15 | toktogul
# Processing Record 1 of Set 16 | opobo
# City not found. Skipping...
# Processing Record 2 of Set 16 | kumo
# Processing Record 3 of Set 16 | luxor
# Processing Record 4 of Set 16 | rio grande
# Processing Record 5 of Set 16 | abakaliki
# Processing Record 6 of Set 16 | constitucion
# Processing Record 7 of Set 16 | mishawaka
# Processing Record 8 of Set 16 | alta floresta
# Processing Record 9 of Set 16 | toguchin
# Processing Record 10 of Set 16 | mannarakkat
# Processing Record 11 of Set 16 | bozdar
# Processing Record 12 of Set 16 | amapa
# Processing Record 13 of Set 16 | terrace bay
# Processing Record 14 of Set 16 | jibuti
# Processing Record 15 of Set 16 | bradley
# Processing Record 16 of Set 16 | trencin
# Processing Record 17 of Set 16 | rumuruti
# Processing Record 18 of Set 16 | freeport
# Processing Record 19 of Set 16 | pasni
# Processing Record 20 of Set 16 | iranshahr
# Processing Record 21 of Set 16 | dipkarpaz
# City not found. Skipping...
# Processing Record 22 of Set 16 | oksfjord
# Processing Record 23 of Set 16 | kazalinsk
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Viransehir  37.2353   39.7631     52.16        63           5
# 1       Maldonado -34.6667  -54.9167     75.22        50           4
# 2       Busselton -33.6500  115.3333     64.04        56          30
# 3  Port Elizabeth -33.9180   25.5701     68.09        93          95
# 4         Qaanaaq  77.4840  -69.3632     -9.33        73          22
# 5       Ostrovnoy  68.0531   39.5131     27.64        90         100
# 6         Ushuaia -54.8000  -68.3000     37.06        75          75
# 7          Bonfim   3.0833  -59.9500     77.34        86         100
# 8         Lusambo  -4.9667   23.4500     68.81        99         100
# 9          Riyadh  24.6877   46.7219     68.14        32          87
#
#    Wind Speed Country Current Description
# 0        4.21      TR           clear sky
# 1        9.62      UY           clear sky
# 2       14.58      AU    scattered clouds
# 3        4.32      ZA     overcast clouds
# 4        5.79      GL          few clouds
# 5       24.32      RU          light snow
# 6       23.02      AR       broken clouds
# 7        2.53      BR     overcast clouds
# 8        1.14      CD          light rain
# 9       14.05      SA     overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Viransehir      TR  37.2353   39.7631     52.16        63           5
# 1       Maldonado      UY -34.6667  -54.9167     75.22        50           4
# 2       Busselton      AU -33.6500  115.3333     64.04        56          30
# 3  Port Elizabeth      ZA -33.9180   25.5701     68.09        93          95
# 4         Qaanaaq      GL  77.4840  -69.3632     -9.33        73          22
# 5       Ostrovnoy      RU  68.0531   39.5131     27.64        90         100
# 6         Ushuaia      AR -54.8000  -68.3000     37.06        75          75
# 7          Bonfim      BR   3.0833  -59.9500     77.34        86         100
# 8         Lusambo      CD  -4.9667   23.4500     68.81        99         100
# 9          Riyadh      SA  24.6877   46.7219     68.14        32          87
#
#    Wind Speed Current Description
# 0        4.21           clear sky
# 1        9.62           clear sky
# 2       14.58    scattered clouds
# 3        4.32     overcast clouds
# 4        5.79          few clouds
# 5       24.32          light snow
# 6       23.02       broken clouds
# 7        2.53     overcast clouds
# 8        1.14          light rain
# 9       14.05     overcast clouds

# %%
# Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data_ into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
